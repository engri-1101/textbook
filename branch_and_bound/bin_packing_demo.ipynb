# %%
# Imports
import numpy as np
import pickle
import scipy.stats as ss
import gurobipy as gp
from gurobipy import GRB

# %% [markdown]
# ### Bin Packing

# %%
def DiscreteRand(mean, std, lb, ub):
    '''Sample from a discretized gaussian distribution truncated to [lb,ub].'''
    x = np.arange(lb, ub+1)
    xU, xL = x + 0.5, x - 0.5 
    prob = ss.norm.cdf(xU, loc=mean ,scale = std) - ss.norm.cdf(xL, loc=mean, scale = std)
    prob = prob / prob.sum() #normalize the probabilities so their sum is 1
    return np.random.choice(x, p = prob)

# %%
def PerfectBinPacking(mean, std, n, v):
    '''Create a perfect bin packing problem with piece size ~N(mean,std) with n bins of volume v'''
    items = {}
    for bins in range(n):
        b = v
        while b > 0:
            if b >= mean:
                item = DiscreteRand(mean,std,0,b)
            else:
                item = b
            b -= item
            if item in items.keys():
                items[item] += 1
            else:
                items.update({item : 1})    
    return items

# %%
def PackBins(items, volume, integer = False):
    '''A model for a bin packing problem.
    
    Args:
        items (Dict[int,int]): Dictionary from item size to number of those items
        volume (int): Volume of bins.
        integer (bool): Solve LP-relaxation if False; otherwise, solve IP.
    '''
    ITEMS = items.keys()
    BINS = range(sum(items.values())) # one item per bin
    v = volume
    count = items
    
    # define model
    m = gp.Model("pack_bins")
    
    # decision variables
    
    x = {} # the number of items of size i that are put in bin j
    for i in ITEMS:
        for j in BINS:
            if integer:
                x[i,j] = m.addVar(vtype=GRB.INTEGER, lb=0, ub=GRB.INFINITY, name=('(i%s, b%s)' % (i,j)))
            else:
                x[i,j] = m.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=GRB.INFINITY, name=('(i%s, b%s)' % (i,j)))
                
    y = {} # 1 if bin i is used; 0 otherwise
    for i in BINS:
        if integer:
            y[i] = m.addVar(vtype=GRB.BINARY, name=('%s' % (i)))
        else:
            y[i] = m.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1, name=('%s' % (i)))
            
     # objective function
    m.setObjective(sum(y[i] for i in BINS), GRB.MINIMIZE)
    
    # constraints
    
    # subject to: bin volume
    for j in BINS:        
        m.addConstr(sum(x[i,j]*i for i in ITEMS) <= v, 'volume_%d' % (j))
        
    # subject to: all items packed
    for i in ITEMS:
        m.addConstr(sum(x[i,j] for j in BINS) == count[i], 'packed_%d' % (i))
        
    # subject to: bin used or not
    for j in BINS:
        M = v
        m.addConstr(sum(x[i,j]*i for i in ITEMS) <= M*y[j], 'used_%d' % (j))
    
    m.optimize()

# %%
#PerfectBinPacking(mean=35, std=5, n=50, v=150)
with open('data-bin_packing/items_168s.pickle', 'rb') as handle:
    items = pickle.load(handle)

# %%
PackBins(items, volume=150)
# Out:
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (mac64)
# Optimize a model with 525 rows, 10164 columns and 30008 nonzeros
# Model fingerprint: 0xf2d49749
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve time: 0.02s
# Presolved: 525 rows, 10164 columns, 30008 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 8.300e+01
#  Factor NZ  : 5.320e+02
#  Factor Ops : 1.052e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.27600327e+02  4.84000000e+01  5.60e+01 2.00e-15  5.88e-01     0s
#    1   5.00000000e+01  4.85218626e+01  2.11e-15 3.75e-16  3.36e-02     0s
#    2   5.00000000e+01  4.99985219e+01  9.33e-16 4.35e-16  3.36e-05     0s
#    3   5.00000000e+01  4.99999985e+01  2.22e-16 1.22e-15  3.36e-08     0s
#    4   5.00000000e+01  5.00000000e+01  6.61e-16 1.78e-15  3.36e-11     0s
#
# Barrier solved model in 4 iterations and 0.04 seconds
# Optimal objective 5.00000000e+01
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 0s
#
#     9881 PPushes remaining with PInf 0.0000000e+00                 0s
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      0s
#
#
# Solved with primal simplex
# Solved in 10165 iterations and 0.06 seconds
# Optimal objective  5.000000000e+01

# %%
PackBins(items, volume=150, integer=True)
# Out:
# Gurobi Optimizer version 9.0.2 build v9.0.2rc0 (mac64)
# Optimize a model with 525 rows, 10164 columns and 30008 nonzeros
# Model fingerprint: 0x222b03d1
# Variable types: 0 continuous, 10164 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Found heuristic solution: objective 79.0000000
# Presolve removed 242 rows and 0 columns
# Presolve time: 0.04s
# Presolved: 283 rows, 10164 columns, 20086 nonzeros
# Variable types: 0 continuous, 10164 integer (2178 binary)
#
# Root relaxation: objective 5.000000e+01, 710 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   50.00000    0   65   79.00000   50.00000  36.7%     -    0s
# H    0     0                      55.0000000   50.00000  9.09%     -    0s
# H    0     0                      54.0000000   50.00000  7.41%     -    0s
# H    0     0                      53.0000000   50.00000  5.66%     -    0s
# H    0     0                      52.0000000   50.00000  3.85%     -    0s
#      0     0   50.00000    0   99   52.00000   50.00000  3.85%     -    0s
#      0     0   50.00000    0   64   52.00000   50.00000  3.85%     -    0s
#      0     2   50.00000    0   50   52.00000   50.00000  3.85%     -    1s
# H  699   382                      51.0000000   50.00000  1.96%  36.0    4s
#    733   341   50.00000   32   64   51.00000   50.00000  1.96%  36.2    5s
#   1333   997   50.00000   82   33   51.00000   50.00000  1.96%  58.4   10s
#   5281  3630   50.00000  322   33   51.00000   50.00000  1.96%  23.9   15s
#   9670  4409   50.00000  371   11   51.00000   50.00000  1.96%  17.0   20s
#  12792  4494   50.00000  342   20   51.00000   50.00000  1.96%  15.7   25s
#  15782  5024   50.00000  347   13   51.00000   50.00000  1.96%  15.3   30s
#  19552  5487 infeasible  372        51.00000   50.00000  1.96%  14.6   35s
#  23257  6441   50.00000  366   17   51.00000   50.00000  1.96%  14.5   40s
#  26996  7258 infeasible  362        51.00000   50.00000  1.96%  13.8   52s
#  29032  8018   50.00000  374   18   51.00000   50.00000  1.96%  13.5   55s
#  32610  8836   50.00000  358   17   51.00000   50.00000  1.96%  12.8   60s
#  37173  9640 infeasible  404        51.00000   50.00000  1.96%  12.1   65s
#  40462  9888 infeasible  397        51.00000   50.00000  1.96%  11.7   70s
#  44786 10593 infeasible  395        51.00000   50.00000  1.96%  11.3   75s
#  47718 10837 infeasible  393        51.00000   50.00000  1.96%  11.2   80s
#  50951 11197   50.00000  401   11   51.00000   50.00000  1.96%  11.1   85s
#  54589 11251 infeasible  409        51.00000   50.00000  1.96%  10.9   90s
#  58402 11818   50.00000  350   24   51.00000   50.00000  1.96%  10.9   95s
#  62094 12130 infeasible  391        51.00000   50.00000  1.96%  10.7  100s
#  65455 12575 infeasible  412        51.00000   50.00000  1.96%  10.6  105s
#  68303 13181   50.00000  390   14   51.00000   50.00000  1.96%  10.7  110s
#  72024 13127 infeasible  388        51.00000   50.00000  1.96%  10.5  115s
#  76210 13507 infeasible  371        51.00000   50.00000  1.96%  10.4  120s
#  78955 13765   50.00000  382   15   51.00000   50.00000  1.96%  10.5  125s
#  82746 13916 infeasible  404        51.00000   50.00000  1.96%  10.4  130s
#  87113 14207   50.00000  372   14   51.00000   50.00000  1.96%  10.2  136s
#  90205 14391   50.00000  397   11   51.00000   50.00000  1.96%  10.2  140s
#  94250 14579 infeasible  394        51.00000   50.00000  1.96%  10.1  146s
#  96639 14768   50.00000  397   10   51.00000   50.00000  1.96%  10.1  150s
#  100518 14814 infeasible  395        51.00000   50.00000  1.96%   9.9  156s
#  103680 14866 infeasible  400        51.00000   50.00000  1.96%   9.9  160s
#  106948 14916 infeasible  392        51.00000   50.00000  1.96%   9.9  165s
#  110232 14987   50.00000  390   12   51.00000   50.00000  1.96%   9.9  170s
#  113998 14924 infeasible  393        51.00000   50.00000  1.96%   9.8  175s
#  117640 15288   50.00000  400   10   51.00000   50.00000  1.96%   9.8  180s
#  122337 15461   50.00000  379   21   51.00000   50.00000  1.96%   9.7  186s
# H124230   597                      50.0000000   50.00000  0.00%   9.7  186s
#
# Cutting planes:
#   Gomory: 22
#   Implied bound: 11
#   MIR: 92
#   StrongCG: 79
#   Flow cover: 4
#   Zero half: 2
#   RLT: 4
#   Relax-and-lift: 1
#
# Explored 124283 nodes (1234973 simplex iterations) in 186.90 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 50 51 52 ... 79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.000000000000e+01, best bound 5.000000000000e+01, gap 0.0000%
