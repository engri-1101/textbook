# %%
from mst import *
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
nodes = pd.read_csv('data/fiber_optic_nodes.csv', index_col=0)
edges = pd.read_csv('data/fiber_optic_edges.csv', index_col=0)
A = adjacency_matrix(nodes, edges)

# %%
tree = prims(A,0)
spanning_tree_cost(A,tree)
# Out:
# 103.0

# %%
tree = kruskals(A)
spanning_tree_cost(A,tree)
# Out:
# 103.0

# %%
tree = reverse_kruskals(A)
spanning_tree_cost(A,tree)
# Out:
# 103.0

# %%
plot_tour(nodes, edges)
# Out:
#   <div class="bk-root" id="aafb4860-c5a7-440c-97e8-de0bf9dc178d" data-root-id="1062"></div>
